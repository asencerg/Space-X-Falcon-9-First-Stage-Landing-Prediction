# %%
# !pip install dash==1.19.0
# !pip install jupyter_dash
# !pip install --upgrade plotly
# Out:
# Requirement already satisfied: dash==1.19.0 in c:\users\zz012t704\anaconda3\lib\site-packages (1.19.0)
# Requirement already satisfied: plotly in c:\users\zz012t704\anaconda3\lib\site-packages (from dash==1.19.0) (5.13.0)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\zz012t704\anaconda3\lib\site-packages (from dash==1.19.0) (1.1.2)
# Requirement already satisfied: future in c:\users\zz012t704\anaconda3\lib\site-packages (from dash==1.19.0) (0.18.2)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\zz012t704\anaconda3\lib\site-packages (from dash==1.19.0) (4.11.2)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\zz012t704\anaconda3\lib\site-packages (from dash==1.19.0) (1.9.0)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\zz012t704\anaconda3\lib\site-packages (from dash==1.19.0) (1.15.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\zz012t704\anaconda3\lib\site-packages (from dash==1.19.0) (1.1.2)
# Requirement already satisfied: flask-compress in c:\users\zz012t704\anaconda3\lib\site-packages (from dash==1.19.0) (1.13)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\zz012t704\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\zz012t704\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.0.3)
# Requirement already satisfied: click>=5.1 in c:\users\zz012t704\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (8.0.4)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\zz012t704\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.0.1)
# Requirement already satisfied: brotli in c:\users\zz012t704\anaconda3\lib\site-packages (from flask-compress->dash==1.19.0) (1.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\zz012t704\anaconda3\lib\site-packages (from plotly->dash==1.19.0) (8.0.1)
# Requirement already satisfied: colorama in c:\users\zz012t704\anaconda3\lib\site-packages (from click>=5.1->Flask>=1.0.4->dash==1.19.0) (0.4.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\zz012t704\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash==1.19.0) (2.0.1)
# Requirement already satisfied: jupyter_dash in c:\users\zz012t704\anaconda3\lib\site-packages (0.4.2)
# Requirement already satisfied: ipython in c:\users\zz012t704\anaconda3\lib\site-packages (from jupyter_dash) (7.31.1)
# Requirement already satisfied: ansi2html in c:\users\zz012t704\anaconda3\lib\site-packages (from jupyter_dash) (1.8.0)
# Requirement already satisfied: nest-asyncio in c:\users\zz012t704\anaconda3\lib\site-packages (from jupyter_dash) (1.5.5)
# Requirement already satisfied: flask in c:\users\zz012t704\anaconda3\lib\site-packages (from jupyter_dash) (1.1.2)
# Requirement already satisfied: ipykernel in c:\users\zz012t704\anaconda3\lib\site-packages (from jupyter_dash) (6.15.2)
# Requirement already satisfied: requests in c:\users\zz012t704\anaconda3\lib\site-packages (from jupyter_dash) (2.28.1)
# Requirement already satisfied: dash in c:\users\zz012t704\anaconda3\lib\site-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: retrying in c:\users\zz012t704\anaconda3\lib\site-packages (from jupyter_dash) (1.3.4)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\zz012t704\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\zz012t704\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: future in c:\users\zz012t704\anaconda3\lib\site-packages (from dash->jupyter_dash) (0.18.2)
# Requirement already satisfied: plotly in c:\users\zz012t704\anaconda3\lib\site-packages (from dash->jupyter_dash) (5.13.0)
# Requirement already satisfied: flask-compress in c:\users\zz012t704\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.13)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\zz012t704\anaconda3\lib\site-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\zz012t704\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: click>=5.1 in c:\users\zz012t704\anaconda3\lib\site-packages (from flask->jupyter_dash) (8.0.4)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\zz012t704\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\zz012t704\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.0.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\zz012t704\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: psutil in c:\users\zz012t704\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (5.9.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\zz012t704\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (0.1.6)
# Requirement already satisfied: debugpy>=1.0 in c:\users\zz012t704\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (1.5.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\zz012t704\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (23.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\zz012t704\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (7.3.4)
# Requirement already satisfied: packaging in c:\users\zz012t704\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (21.3)
# Requirement already satisfied: tornado>=6.1 in c:\users\zz012t704\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: traitlets>=5.1.0 in c:\users\zz012t704\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\zz012t704\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\zz012t704\anaconda3\lib\site-packages (from ipython->jupyter_dash) (3.0.20)
# Requirement already satisfied: pickleshare in c:\users\zz012t704\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: backcall in c:\users\zz012t704\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: pygments in c:\users\zz012t704\anaconda3\lib\site-packages (from ipython->jupyter_dash) (2.11.2)
# Requirement already satisfied: colorama in c:\users\zz012t704\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.4.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\zz012t704\anaconda3\lib\site-packages (from ipython->jupyter_dash) (63.4.1)
# Requirement already satisfied: decorator in c:\users\zz012t704\anaconda3\lib\site-packages (from ipython->jupyter_dash) (5.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\zz012t704\anaconda3\lib\site-packages (from requests->jupyter_dash) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\zz012t704\anaconda3\lib\site-packages (from requests->jupyter_dash) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zz012t704\anaconda3\lib\site-packages (from requests->jupyter_dash) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\zz012t704\anaconda3\lib\site-packages (from requests->jupyter_dash) (2.0.4)
# Requirement already satisfied: six>=1.7.0 in c:\users\zz012t704\anaconda3\lib\site-packages (from retrying->jupyter_dash) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\zz012t704\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\zz012t704\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: entrypoints in c:\users\zz012t704\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\zz012t704\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (4.11.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\zz012t704\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (2.8.2)
# Requirement already satisfied: wcwidth in c:\users\zz012t704\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: brotli in c:\users\zz012t704\anaconda3\lib\site-packages (from flask-compress->dash->jupyter_dash) (1.0.9)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\zz012t704\anaconda3\lib\site-packages (from packaging->ipykernel->jupyter_dash) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\zz012t704\anaconda3\lib\site-packages (from plotly->dash->jupyter_dash) (8.0.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\zz012t704\anaconda3\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel->jupyter_dash) (302)
# Requirement already satisfied: plotly in c:\users\zz012t704\anaconda3\lib\site-packages (5.13.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\zz012t704\anaconda3\lib\site-packages (from plotly) (8.0.1)

# %%
# Import required libraries
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output, State
import plotly.graph_objects as go
import plotly.express as px
from dash import no_update

# %%
# Read the airline data into pandas dataframe
spacex_df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# %%
# Create a dash application
app = dash.Dash(__name__)

# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                dcc.Dropdown(id='site-dropdown',
                                            options=[
                                                {'label': 'All Sites', 'value': 'ALL'},
                                                {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
                                                {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
                                                {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
                                                {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
                                            ],
                                            value='ALL',
                                            placeholder="Select a Launch Site here",
                                            searchable=True
                                            ),
                                html.Br(),

                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                #dcc.RangeSlider(id='payload-slider',...)
                                
                                dcc.RangeSlider(id='payload-slider',
                                                min=0, max=10000, step=1000,
                                                marks={0: '0', 2500: '2500', 5000: '5000', 7500: '7500', 10000: '10000'},
                                                value=[min_payload, max_payload]),
                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])

# %%
# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
# Function decorator to specify function input and output
@app.callback(Output(component_id='success-pie-chart', component_property='figure'),
              Input(component_id='site-dropdown', component_property='value'))
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
        names='Launch Site', 
        title='Total Success Launches By Site')
        return fig
    else:
        # return the outcomes piechart for a selected site
        filtered_df = spacex_df[spacex_df['Launch Site'] == entered_site]
        filtered_df = filtered_df.groupby(['Launch Site', 'class']).size().reset_index(name='class count')
        fig = px.pie(filtered_df, values='class count', 
        names='class',
        title=f'Total Success Launched for site {entered_site}')
        return fig

# %%
spacex_df.pivot_table('class', index='Launch Site' )
# Out:
#                  class
# Launch Site
# CCAFS LC-40   0.269231
# CCAFS SLC-40  0.428571
# KSC LC-39A    0.769231
# VAFB SLC-4E   0.400000

# %%
# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(Output(component_id='success-payload-scatter-chart', component_property='figure'),
              [Input(component_id='site-dropdown', component_property='value'), 
              Input(component_id='payload-slider', component_property='value')])
def get_scatter_chart(entered_site, payload):
    low, high = payload
    filtered_df = spacex_df[(spacex_df['Payload Mass (kg)'] > low) & (spacex_df['Payload Mass (kg)'] < high)]       
    if entered_site == 'ALL':
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class', 
        color='Booster Version Category',
        title='Correlation between Payload and Success for all Sites')
        return fig
    else:
        fig = px.scatter(filtered_df[filtered_df['Launch Site'] == entered_site],
        x='Payload Mass (kg)', y='class',
        color='Booster Version Category',
        title=f'Correlation between Payload and Success for site {entered_site}')
        return fig

# Run the app
if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [28/Jan/2023 09:45:42] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jan/2023 09:45:42] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jan/2023 09:45:42] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jan/2023 09:45:42] "GET /_favicon.ico?v=1.19.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jan/2023 09:45:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jan/2023 09:45:43] "POST /_dash-update-component HTTP/1.1" 200 -
